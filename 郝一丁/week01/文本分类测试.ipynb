# %% [markdown]
# ## 运行.py文件的代码，展示模型输出结果

# %% [markdown]
# ### 1.传统模型（MultinomialNB）

# %%
from 文本分类 import run_ml

model, vector = run_ml()
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\94557\AppData\Local\Temp\jieba.cache
# Loading model cost 0.526 seconds.
# Prefix dict has been built successfully.
# MultinomialNB()
#
# 预测结果:
# 待预测文本: 帮我查一下明天从北京到伦敦的联航机票
# 预测结果: Travel-Query
#
# 待预测文本: 随机播放一首周杰伦不喜欢听的歌
# 预测结果: Music-Play
#
# 待预测文本: 我上次生日所在那天是什么节日
# 预测结果: Calendar-Query

# %% [markdown]
# ### 2.大模型（chatgpt）

# %%
import os
os.environ["HTTP_PROXY"]  = "http://127.0.0.1:4780"
os.environ["HTTPS_PROXY"] = "http://127.0.0.1:4780"

# %%
import os
os.environ["OPENAI_API_KEY"] = "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"
from 文本分类 import run_llm

llm_cls = run_llm()

print(llm_cls())
# Out:
# 文本: 帮我查一下明天从北京到伦敦的联航机票
# 大语言模型: Travel-Query
# ------------------------------
# 文本: 随机播放一首周杰伦不喜欢听的歌
# 大语言模型: Music-Play
# ------------------------------
# 文本: 我上次生日所在那天是什么节日
# 大语言模型: Calendar-Query
# ------------------------------
# Video-Play
